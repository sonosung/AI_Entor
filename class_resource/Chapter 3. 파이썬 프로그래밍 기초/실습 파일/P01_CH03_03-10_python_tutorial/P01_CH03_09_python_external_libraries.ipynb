# %% [markdown]
# # Python 외부 라이브러리
#
# 이 노트북은 Python에서 사용할 수 있는 몇 가지 주요 외부 라이브러리에 대해 소개합니다. 이들 라이브러리는 특정 작업을 수행할 때 강력한 기능과 편리함을 제공합니다.
#
# ## 외부 라이브러리 개요
#
# 외부 라이브러리는 Python 표준 라이브러리에 포함되어 있지 않지만, 다양한 소스를 통해 설치하여 사용할 수 있습니다. 주로 `pip` 명령어를 사용하여 설치합니다.
#
# ## 인기 있는 외부 라이브러리
#
# ### NumPy
#
# - 수치 계산을 위한 라이브러리입니다.
# - 고성능 다차원 배열 객체와 이를 다루는 도구를 제공합니다.

# %%
# !pip install numpy

# %%
sys.path.append('c:\\users\\msh07\\miniconda3\\lib\\site-packages')

# %%
# !pip install numpy --upgrade

# %%
import numpy as np

a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
x = np.array([[1,2],
              [3,4]])
y = np.array([[1,0],
              [0,1]])

# %%
np.matmul(x, y)
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# ### Matplotlib
#
# - 데이터를 차트나 그래프로 시각화하는 데 사용되는 라이브러리입니다.
# - 다양한 형태의 그래프를 쉽게 그릴 수 있습니다.

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------------------------------- ------ 6.8/8.0 MB 35.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 33.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 36.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 28.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 4, 6]
plt.plot(x, y)
plt.show()

# %%
def pseudo_function(x, x_i, n_data):
    n_wave = 5
    exp_max = 1
    exp_min = -1
    bias = 0.5
    a = 1.5
    
    radian_unit = (np.pi * n_wave) / n_data
    exp_unit = (exp_max - exp_min) / n_data 
    
    y = np.sin(x_i*radian_unit)* np.exp(exp_max-(exp_unit*x_i)) + bias + a*x
    
    return y

# %%
n_data = 100
x_range = (-1, 1)

X_train = np.linspace(-1, 1, n_data,dtype=np.float32)
Y_train = np.array([pseudo_function(x,x_i,n_data) for x_i, x in enumerate(list(X_train))], dtype=np.float32)
plt.plot(X_train, Y_train, 'ro', alpha=0.4, color='black')
# Out:
# C:\Users\msh07\AppData\Local\Temp\ipykernel_18336\2918769608.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(X_train, Y_train, 'ro', alpha=0.4, color='black')

# %% [markdown]
# ### Pandas
#
# - 데이터 분석을 위한 라이브러리입니다.
# - 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있습니다.

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----------------------- ---------------- 6.8/11.5 MB 35.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 32.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

data = {'name': ['Alice', 'Bob'], 'age': [24, 28]}
df = pd.DataFrame(data)
df
# Out:
#     name  age
# 0  Alice   24
# 1    Bob   28

# %%
df["age"].max()
# Out:
# np.int64(28)

# %%
df["age"].min()
# Out:
# np.int64(24)

# %%
df["age"].mean()
# Out:
# np.float64(26.0)

# %% [markdown]
# ### Requests
#
# - HTTP 요청을 쉽게 보낼 수 있는 라이브러리입니다.
# - REST API를 사용하여 데이터를 주고받을 때 유용합니다.

# %%
# !pip install requests

# %%
import requests

response = requests.get('https://api.github.com')
print(response.status_code)
# Out:
# 200

# %%
response = requests.get('https://naver.com')
print(response.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %% [markdown]
# ## 라이브러리 활용
#
# 이러한 외부 라이브러리를 활용하면 데이터 분석, 수학 계산, 그래프 그리기, 웹 스크레이핑 등 다양한 작업을 보다 쉽고 효율적으로 수행할 수 있습니다. 각 라이브러리에 대한 보다 자세한 정보와 사용법은 공식 문서나 다양한 온라인 자료를 참조하십시오.
